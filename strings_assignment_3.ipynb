# %% [markdown]
# 1.Write a Python program to count the number of vowels in a string.
#
# input : hasdfgeuionhjl

# %%
# write your code here
str="hasdfgeuionhjl"
vowels=0
for i in str:
      if(i=='a' or i=='e' or i=='i' or i=='o' or i=='u' or i=='A' or i=='E' or i=='I' or i=='O' or i=='U'):
            vowels=vowels+1
print(vowels)
# Out:
# 5

# %% [markdown]
# 2.Write a Python program to count the occurrences of each word in a sentence.
#
# input : hi hello hi and and hi more and more programming

# %%
# write your code here
str="hi hello hi and and hi more and more programming"
words=str.split()
word_count={}
for i in words:
    if i in word_count:
        word_count[i]+=1
    else:
        word_count[i]=1
print(word_count)
# Out:
# {'hi': 3, 'hello': 1, 'and': 3, 'more': 2, 'programming': 1}

# %% [markdown]
# 3.In python how can you differentiate strings and lists. Give atleast 5 different comparisons between them.

# %% [markdown]
# Answer:
# 1. Strings are immutable but lists are mutable.
# 2. Strings only contains characters but where as lists contain any datatype elements such as strings,int,boolean and objects.
# 3. strings are represented using '' or "" or """ """ but lists are represented using [].
# 4. Both uses slicing for the substring or sublist.
# 5. Uses len() method to find the length of the string and list.

# %% [markdown]
# 4.Write a string for your own of approximately 40 in length and perform any 5 different string operations on that.

# %%
#Write your code here
str="Strings are immutable but lists are mutable."
#length of the string
print(len(str))
#reverse the string
print(str[::-1])
#substring
print(str[23:34])
#Uppercase
print(str.upper())
#Lowercase
print(str.lower())
# Out:
# 44
# .elbatum era stsil tub elbatummi era sgnirtS
# ut lists ar
# STRINGS ARE IMMUTABLE BUT LISTS ARE MUTABLE.
# strings are immutable but lists are mutable.

# %% [markdown]
# 5.Explain the concatination in strings with a neat example.

# %%
#write your code and explanation here
s1="Hello"
s2="World!"
s=s1+s2
print(s)

str=f"{s1} {s2}"
print(str)
# Out:
# HelloWorld!
# Hello World!
